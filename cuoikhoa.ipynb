# %%
print("Hello World")
# Out:
# Hello World

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
import plotly.express as px

# %%
df = pd.read_csv("cardiovascular-disease-death-rate-who-mdb.csv")
df
# Out:
#          Entity Code  Year  \
# 0       Albania  ALB  1987
# 1       Albania  ALB  1988
# 2       Albania  ALB  1989
# 3       Albania  ALB  1992
# 4       Albania  ALB  1993
# ...         ...  ...   ...
# 4771  Venezuela  VEN  2012
# 4772  Venezuela  VEN  2013
# 4773  Venezuela  VEN  2014
# 4774  Venezuela  VEN  2015
# 4775  Venezuela  VEN  2016
#
#       Age-standardized deaths from cardiovascular diseases in both sexes in those aged all ages per 100,000 people
# 0                                             331.37842
# 1                                             333.62150
# 2                                             339.13010
# 3                                             289.65850
# 4                                             264.37045
# ...                                                 ...
# 4771                                          201.83017
# 4772                                          196.01802
# 4773                                          212.63083
# ...

# %%
df_venezuela = df.loc[df['Entity']=='Venezuela', :]
df_venezuela
# Out:
#          Entity Code  Year  \
# 4717  Venezuela  VEN  1955
# 4718  Venezuela  VEN  1956
# 4719  Venezuela  VEN  1957
# 4720  Venezuela  VEN  1958
# 4721  Venezuela  VEN  1959
# 4722  Venezuela  VEN  1960
# 4723  Venezuela  VEN  1961
# 4724  Venezuela  VEN  1962
# 4725  Venezuela  VEN  1963
# 4726  Venezuela  VEN  1964
# 4727  Venezuela  VEN  1965
# 4728  Venezuela  VEN  1966
# 4729  Venezuela  VEN  1967
# 4730  Venezuela  VEN  1968
# 4731  Venezuela  VEN  1969
# 4732  Venezuela  VEN  1970
# 4733  Venezuela  VEN  1971
# 4734  Venezuela  VEN  1972
# 4735  Venezuela  VEN  1973
# 4736  Venezuela  VEN  1974
# 4737  Venezuela  VEN  1975
# 4738  Venezuela  VEN  1976
# 4739  Venezuela  VEN  1977
# 4740  Venezuela  VEN  1978
# 4741  Venezuela  VEN  1979
# 4742  Venezuela  VEN  1980
# 4743  Venezuela  VEN  1981
# 4744  Venezuela  VEN  1982
# 4745  Venezuela  VEN  1983
# 4746  Venezuela  VEN  1985
# 4747  Venezuela  VEN  1986
# 4748  Venezuela  VEN  1987
# 4749  Venezuela  VEN  1988
# ...

# %%
# List of columns with missing values
columns_with_missing = df.columns[df.isnull().any()]

# Impute numerical columns with mean
numerical_columns = df.select_dtypes(include=['float64'])
numerical_columns = numerical_columns.columns[numerical_columns.isnull().any()]
df[numerical_columns] = df[numerical_columns].fillna(df[numerical_columns].mean())

# %%
x= df_venezuela["Year"]
y= df_venezuela["Age-standardized deaths from cardiovascular diseases in both sexes in those aged all ages per 100,000 people"]

# %%
plt.figure(figsize=(80, 40))
plt.plot(x, y, marker='o', markersize=20, linestyle="-", linewidth=5)

plt.xlabel('Year - Entity', fontsize=50)
plt.ylabel('People died', fontsize=50)
plt.title("Age-standardized deaths from cardiovascular diseases in both sexes in those aged all ages per 100,000 people in Venezuela", fontsize=50)
# Out:
# Text(0.5, 1.0, 'Age-standardized deaths from cardiovascular diseases in both sexes in those aged all ages per 100,000 people in Venezuela')

# %%
df_canada = df.loc[df['Entity']=='Canada', :]
df_canada
# Out:
#      Entity Code  Year  \
# 710  Canada  CAN  1950
# 711  Canada  CAN  1951
# 712  Canada  CAN  1952
# 713  Canada  CAN  1953
# 714  Canada  CAN  1954
# ..      ...  ...   ...
# 778  Canada  CAN  2018
# 779  Canada  CAN  2019
# 780  Canada  CAN  2020
# 781  Canada  CAN  2021
# 782  Canada  CAN  2022
#
#      Age-standardized deaths from cardiovascular diseases in both sexes in those aged all ages per 100,000 people
# 710                                         469.767430
# 711                                         471.268860
# 712                                         471.400300
# 713                                         470.262150
# 714                                         454.737550
# ..                                                 ...
# 778                                          82.328000
# 779                                          80.143520
# 780                                          80.530170
# 781                                          78.677986
# ...

# %%
# List of columns with missing values
columns_with_missing = df.columns[df.isnull().any()]

# Impute numerical columns with mean
numerical_columns = df.select_dtypes(include=['float64'])
numerical_columns = numerical_columns.columns[numerical_columns.isnull().any()]
df[numerical_columns] = df[numerical_columns].fillna(df[numerical_columns].mean())

# %%
x= df_canada["Year"]
y= df_canada["Age-standardized deaths from cardiovascular diseases in both sexes in those aged all ages per 100,000 people"]

# %%
plt.figure(figsize=(80, 40))
plt.plot(x, y, linewidth=5)

plt.xlabel('Year - Entity', fontsize=50)
plt.ylabel('People died', fontsize=50)
plt.title("Age-standardized deaths from cardiovascular diseases in both sexes in those aged all ages per 100,000 people in Canada", fontsize=50)
# Out:
# Text(0.5, 1.0, 'Age-standardized deaths from cardiovascular diseases in both sexes in those aged all ages per 100,000 people in Canada')

# %%
df_australia = df.loc[df['Entity']=='Australia', :]
df_australia
# Out:
#         Entity Code  Year  \
# 161  Australia  AUS  1950
# 162  Australia  AUS  1951
# 163  Australia  AUS  1952
# 164  Australia  AUS  1953
# 165  Australia  AUS  1954
# ..         ...  ...   ...
# 228  Australia  AUS  2018
# 229  Australia  AUS  2019
# 230  Australia  AUS  2020
# 231  Australia  AUS  2021
# 232  Australia  AUS  2022
#
#      Age-standardized deaths from cardiovascular diseases in both sexes in those aged all ages per 100,000 people
# 161                                         493.109500
# 162                                         512.759500
# 163                                         516.450500
# 164                                         497.559300
# 165                                         501.369630
# ..                                                 ...
# 228                                          75.062035
# 229                                          76.416580
# 230                                          69.159790
# ...

# %%
# List of columns with missing values
columns_with_missing = df.columns[df.isnull().any()]

# Impute numerical columns with mean
numerical_columns = df.select_dtypes(include=['float64'])
numerical_columns = numerical_columns.columns[numerical_columns.isnull().any()]
df[numerical_columns] = df[numerical_columns].fillna(df[numerical_columns].mean())

# %%
x= df_australia["Year"]
y= df_australia["Age-standardized deaths from cardiovascular diseases in both sexes in those aged all ages per 100,000 people"]

# %%
plt.figure(figsize=(60, 30))
plt.plot(x, y, linewidth=5)

plt.xlabel('Year - Entity', fontsize=60)
plt.xticks(fontsize=30)
plt.ylabel('People died', fontsize=60)
plt.yticks(fontsize=30)
plt.title("Age-standardized deaths from cardiovascular diseases in both sexes in those aged all ages per 100,000 people in Australia", fontsize=50)
# Out:
# Text(0.5, 1.0, 'Age-standardized deaths from cardiovascular diseases in both sexes in those aged all ages per 100,000 people in Australia')

# %%
df_japan = df.loc[df['Entity']=='Japan', :]
df_japan
# Out:
#      Entity Code  Year  \
# 2277  Japan  JPN  1950
# 2278  Japan  JPN  1951
# 2279  Japan  JPN  1952
# 2280  Japan  JPN  1953
# 2281  Japan  JPN  1954
# ...     ...  ...   ...
# 2344  Japan  JPN  2017
# 2345  Japan  JPN  2018
# 2346  Japan  JPN  2019
# 2347  Japan  JPN  2020
# 2348  Japan  JPN  2021
#
#       Age-standardized deaths from cardiovascular diseases in both sexes in those aged all ages per 100,000 people
# 2277                                          304.17240
# 2278                                          326.88290
# 2279                                          324.30500
# 2280                                          336.36145
# 2281                                          319.79074
# ...                                                 ...
# 2344                                           69.77603
# 2345                                           68.42335
# 2346                                           66.68943
# ...

# %%
# List of columns with missing values
columns_with_missing = df.columns[df.isnull().any()]

# Impute numerical columns with mean
numerical_columns = df.select_dtypes(include=['float64'])
numerical_columns = numerical_columns.columns[numerical_columns.isnull().any()]
df[numerical_columns] = df[numerical_columns].fillna(df[numerical_columns].mean())

# %%
x= df_japan["Year"]
y= df_japan["Age-standardized deaths from cardiovascular diseases in both sexes in those aged all ages per 100,000 people"]

# %%
plt.figure(figsize=(60, 30))
plt.plot(x, y, linewidth=5)

plt.xlabel('Year - Entity', fontsize=60)
plt.xticks(fontsize=30)
plt.ylabel('People died', fontsize=60)
plt.yticks(fontsize=30)
plt.title("Age-standardized deaths from cardiovascular diseases in both sexes in those aged all ages per 100,000 people in Japan", fontsize=50)
# Out:
# Text(0.5, 1.0, 'Age-standardized deaths from cardiovascular diseases in both sexes in those aged all ages per 100,000 people in Japan')

# %%
df_mexico= df.loc[df['Entity']=='Mexico', :]
df_mexico
# Out:
#       Entity Code  Year  \
# 2800  Mexico  MEX  1955
# 2801  Mexico  MEX  1956
# 2802  Mexico  MEX  1957
# 2803  Mexico  MEX  1958
# 2804  Mexico  MEX  1959
# ...      ...  ...   ...
# 2862  Mexico  MEX  2017
# 2863  Mexico  MEX  2018
# 2864  Mexico  MEX  2019
# 2865  Mexico  MEX  2020
# 2866  Mexico  MEX  2021
#
#       Age-standardized deaths from cardiovascular diseases in both sexes in those aged all ages per 100,000 people
# 2800                                          207.53175
# 2801                                          211.11575
# 2802                                          216.73924
# 2803                                          186.12761
# 2804                                          188.20663
# ...                                                 ...
# 2862                                          148.67030
# 2863                                          150.48657
# 2864                                          151.37212
# ...

# %%
# List of columns with missing values
columns_with_missing = df.columns[df.isnull().any()]

# Impute numerical columns with mean
numerical_columns = df.select_dtypes(include=['float64'])
numerical_columns = numerical_columns.columns[numerical_columns.isnull().any()]
df[numerical_columns] = df[numerical_columns].fillna(df[numerical_columns].mean())

# %%
x= df_mexico["Year"]
y= df_mexico["Age-standardized deaths from cardiovascular diseases in both sexes in those aged all ages per 100,000 people"]

# %%
plt.figure(figsize=(80, 40))

plt.figure(figsize=(60, 30))
plt.plot(x, y, marker='o', markersize=20, linestyle="-", linewidth=5)

plt.xlabel('Year - Entity', fontsize=60)
plt.xticks(fontsize=30)
plt.ylabel('People died', fontsize=60)
plt.yticks(fontsize=30)
plt.title("Age-standardized deaths from cardiovascular diseases in both sexes in those aged all ages per 100,000 people in Mexico", fontsize=50)
# Out:
# Text(0.5, 1.0, 'Age-standardized deaths from cardiovascular diseases in both sexes in those aged all ages per 100,000 